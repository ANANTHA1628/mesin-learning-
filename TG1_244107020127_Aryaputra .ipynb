# %% [markdown]
# <a href="https://colab.research.google.com/github/ANANTHA1628/mesin-learning-/blob/main/TG1_244107020127_Aryaputra%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne

# %%
# !pip install pyprep

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install scikit-learn wfdb ishneholterlib pytest pytest-cov
# !pip install --no-deps pyecg
# Out:
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 5.4 MB/s eta 0:00:00
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %%
import pyprep
import scipy
import wandb
import pyecg

print("Semua library berhasil di-install!")
# Out:
# /usr/local/lib/python3.13/dist-packages/pyecg/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# Semua library berhasil di-install!
